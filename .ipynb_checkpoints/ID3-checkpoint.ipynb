# %%
# Decision Tree Classifier, using ID3 Algorithm
# Dataset: World Economic Forum "Readiness for the future of production report 2018"  
#   https://www.weforum.org/reports/readiness-for-the-future-of-production-report-2018

# Created by: Andi Sama
# NIM: 2540136324
# Date created: April 2, 2023
# Last modified: April 7, 2023

# Program: Doctor of Computer Science (DCS)
# Institution: Binus University
# Subject: ISYS90219045 Advanced Knowledge System
# Lecturer: Prof. Dr. Sfenrianto, S.Kom, M.Kom

# %%
import pandas as pd
# import numpy as np
import matplotlib.pyplot as plt

from sklearn.tree import DecisionTreeClassifier
# from sklearn.inspection import DecisionBoundaryDisplay

# %%
df = pd.read_csv("data\WEF_FOP2.csv")
features = df[["Technology & Innovation","Human Capital","Global Trade & Investment","Institutional Framework", 
               "Sustainable Resources","Demand Environment"]]
classes = df["Quartile"]

# %%
df.head()
# Out:
#         Country  Quartile  Technology & Innovation  Human Capital  \
# 0        Oyprus         1                     5.01           6.44
# 1         Chile         1                     4.36           5.32
# 2  Saudi Arabia         1                     4.50           5.21
# 3        Latvia         1                     4.54           5.63
# 4     Mauritius         1                     5.08           5.15
#
#    Global Trade & Investment  Institutional Framework  Sustainable Resources  \
# 0                       6.36                     6.28                   5.33
# 1                       6.02                     6.91                   6.87
# 2                       5.41                     6.19                   5.00
# 3                       5.64                     6.42                   8.44
# 4                       5.95                     6.48                   6.21
#
#    Demand Environment
# 0                3.80
# 1                4.89
# 2                6.19
# 3                3.45
# 4                3.48

# %%
# take a look more at the data
pd.set_option('display.max_rows', 10)
df
# Out:
#             Country  Quartile  Technology & Innovation  Human Capital  \
# 0            Oyprus         1                     5.01           6.44
# 1             Chile         1                     4.36           5.32
# 2      Saudi Arabia         1                     4.50           5.21
# 3            Latvia         1                     4.54           5.63
# 4         Mauritius         1                     5.08           5.15
# ..              ...       ...                      ...            ...
# 53  Kyrgyz Republic         4                     2.56           4.15
# 54           Uganda         4                     3.19           3.01
# 55         Ethiopia         4                     2.57           3.42
# 56         Tanzania         4                     2.82           2.85
# 57         Cameroon         4                     3.11           3.18
#
#     Global Trade & Investment  Institutional Framework  Sustainable Resources  \
# 0                        6.36                     6.28                   5.33
# 1                        6.02                     6.91                   6.87
# 2                        5.41                     6.19                   5.00
# 3                        5.64                     6.42                   8.44
# 4                        5.95                     6.48                   6.21
# ..                        ...                      ...                    ...
# 53                       3.86                     3.41                   2.89
# 54                       1.98                     4.55                   5.70
# 55                       1.97                     4.27                   4.38
# 56                       2.18                     4.39                   4.93
# 57                       2.58                     3.36                   4.97
#
#     Demand Environment
# 0                 3.80
# 1                 4.89
# 2                 6.19
# 3                 3.45
# 4                 3.48
# ..                 ...
# 53                3.24
# 54                3.17
# 55                4.17
# 56                3.88
# 57                3.63
#
# [58 rows x 8 columns]

# %%
features
# Out:
#     Technology & Innovation  Human Capital  Global Trade & Investment  \
# 0                      5.01           6.44                       6.36
# 1                      4.36           5.32                       6.02
# 2                      4.50           5.21                       5.41
# 3                      4.54           5.63                       5.64
# 4                      5.08           5.15                       5.95
# ..                      ...            ...                        ...
# 53                     2.56           4.15                       3.86
# 54                     3.19           3.01                       1.98
# 55                     2.57           3.42                       1.97
# 56                     2.82           2.85                       2.18
# 57                     3.11           3.18                       2.58
#
#     Institutional Framework  Sustainable Resources  Demand Environment
# 0                      6.28                   5.33                3.80
# 1                      6.91                   6.87                4.89
# 2                      6.19                   5.00                6.19
# 3                      6.42                   8.44                3.45
# 4                      6.48                   6.21                3.48
# ..                      ...                    ...                 ...
# 53                     3.41                   2.89                3.24
# 54                     4.55                   5.70                3.17
# 55                     4.27                   4.38                4.17
# 56                     4.39                   4.93                3.88
# 57                     3.36                   4.97                3.63
#
# [58 rows x 6 columns]

# %%
# # let's inspect the target data for our rule-based algorithm
classes
# Out:
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1
#      ..
# 53    4
# 54    4
# 55    4
# 56    4
# 57    4
# Name: Quartile, Length: 58, dtype: int64

# %%
# create a DecisionTreeClassifier object
clf = DecisionTreeClassifier(criterion='entropy')

# train the model on the data
clf.fit(features, classes)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
from sklearn.tree import plot_tree

plt.figure()
featurenames = ["TechInn", "HmCap", "GlbTrdInv", "InstFrm", "SusRsc", "DmdEnv"]
classnames = ["Q1", "Q2", "Q3", "Q4"]
trained = DecisionTreeClassifier().fit(features, classes)
plot_tree(trained, feature_names=featurenames, class_names=classnames, filled=True)
plt.title("Decision tree trained on all features")
# plt.show()
resolution = 1200
plt.savefig("ASM_decision_tree_ID3.png", format="png", dpi=resolution)

# %%
# df.shape
df
# Out:
#             Country  Quartile  Technology & Innovation  Human Capital  \
# 0            Oyprus         1                     5.01           6.44
# 1             Chile         1                     4.36           5.32
# 2      Saudi Arabia         1                     4.50           5.21
# 3            Latvia         1                     4.54           5.63
# 4         Mauritius         1                     5.08           5.15
# ..              ...       ...                      ...            ...
# 53  Kyrgyz Republic         4                     2.56           4.15
# 54           Uganda         4                     3.19           3.01
# 55         Ethiopia         4                     2.57           3.42
# 56         Tanzania         4                     2.82           2.85
# 57         Cameroon         4                     3.11           3.18
#
#     Global Trade & Investment  Institutional Framework  Sustainable Resources  \
# 0                        6.36                     6.28                   5.33
# 1                        6.02                     6.91                   6.87
# 2                        5.41                     6.19                   5.00
# 3                        5.64                     6.42                   8.44
# 4                        5.95                     6.48                   6.21
# ..                        ...                      ...                    ...
# 53                       3.86                     3.41                   2.89
# 54                       1.98                     4.55                   5.70
# 55                       1.97                     4.27                   4.38
# 56                       2.18                     4.39                   4.93
# 57                       2.58                     3.36                   4.97
#
#     Demand Environment
# 0                 3.80
# 1                 4.89
# 2                 6.19
# 3                 3.45
# 4                 3.48
# ..                 ...
# 53                3.24
# 54                3.17
# 55                4.17
# 56                3.88
# 57                3.63
#
# [58 rows x 8 columns]

# %%
features.shape
# Out:
# (58, 6)

# %%
# # prediction from a single sample data, just to make sure for validation
# new_data=([4.5,5.21,5.41,6.19,5,6.19])    # saudi arabia
# new_features=pd.DataFrame(new_data).transpose()
# # n=new_features[0].to_frame()
# n=new_features
# clf.predict(n)
# n.shape

# %%
# prediction from a few sample data, just to make sure for validation
my_data=([4.5,5.21,5.41,6.19,5,6.19],             # saudi arabia, Q1
          [4,4.99,5.06,4.59,4.09,6.38],           # indonesia, Q2
          [3.18,3.65,2.72,3.67,2.88,5.37],        # pakistan, Q4
          [4.01,4.23,4.11,4.17,3.97,4.68])        # with one new data - just a fixed randomized data
new_features=pd.DataFrame(my_data).transpose()

# %%
new_features.shape
# Out:
# (6, 4)

# %%
# n=new_features[0].to_frame()
new_features
# Out:
#       0     1     2     3
# 0  4.50  4.00  3.18  4.01
# 1  5.21  4.99  3.65  4.23
# 2  5.41  5.06  2.72  4.11
# 3  6.19  4.59  3.67  4.17
# 4  5.00  4.09  2.88  3.97
# 5  6.19  6.38  5.37  4.68

# %%
clf.predict(new_features.transpose())
# Out:
# C:\Users\ThinkPad\anaconda3\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1, 4, 2, 2, 2, 1, 4, 4], dtype=int64)

# %%
# new_data=([4.5,5.21,5.41,6.19,5,6.19])

# %%
import random
score_min_DriverOfProduction = 3.24
score_max_DriverOfProduction = 5.65

# %%
# Generate eight randomized data for all six features each, within the boundary of the trained data 
# the boundaries are the minimum and maximum scores of Driver of Production
#
# new_data_headers = ("Technology & Innovation", "Human Capital", "Global Trade & Investment",
#                     "Institutional Framework", "Sustainable Resources", "Demand Environment")
new_data = []
# new_data.append(featurenames)
rows, cols = 8, 6
for i in range(rows):
    col = []
    for j in range (cols):
        col.append(round(random.uniform(score_min_DriverOfProduction, score_max_DriverOfProduction), 2))
    new_data.append(col)

# %%
new_data
# Out:
# [[3.94, 4.48, 5.36, 5.17, 4.16, 5.6],
#  [5.07, 4.04, 5.5, 4.45, 5.02, 4.45],
#  [4.75, 3.6, 4.92, 5.03, 3.88, 3.9],
#  [5.46, 4.31, 3.59, 4.53, 5.08, 4.39],
#  [5.52, 3.93, 4.2, 3.71, 3.59, 4.4],
#  [5.39, 5.63, 3.67, 3.61, 4.12, 4.52],
#  [3.31, 5.62, 3.42, 4.06, 4.62, 4.36],
#  [4.57, 5.23, 4.6, 4.45, 3.69, 3.51]]

# %%
new_features=pd.DataFrame(new_data).transpose()
clf.predict(new_features.transpose())
# Out:
# C:\Users\ThinkPad\anaconda3\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1, 1, 1, 2, 2, 4, 3, 2], dtype=int64)
